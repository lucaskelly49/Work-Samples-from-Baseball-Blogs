# %% [markdown]
# # Max Scherzer Game 1 World Series

# %% [markdown]
# ### Libraries

# %%
#apache http library
import requests

#XML parsing
import xml.etree.ElementTree as ET

import os
import pandas as pd
import numpy as np
from matplotlib.patches import Rectangle
from numpy.random import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline
from termcolor import colored

# %% [markdown]
# ### Get player data

# %%
url = 'http://gd2.mlb.com/components/game/mlb/year_2019/month_10/day_22/gid_2019_10_22_wasmlb_houmlb_1/players.xml'
resp = requests.get(url)
print(colored(resp, 'blue'))
# Out:
# <Response [200]>

# %%
xmlfile = 'WSH_HOU_Players_Game1.xml'
with open(xmlfile, 'wb') as f:
    f.write(resp.content)
statinfo = os.stat(xmlfile)

# %%
# pull in players <game><team><player>
tree = ET.parse(xmlfile)
game = tree.getroot()
teams = game.findall('./team')
teams
# Out:
# [<Element 'team' at 0x117b366b0>, <Element 'team' at 0x117af3f50>]

# %%
PlayerDict = {}

for team in teams:
    print(team.attrib.get('name'))
    players = team.findall('player')
    for player in players:
        print('', player.attrib.get('id'), player.attrib.get('first'), player.attrib.get('last'))
        PlayerDict[player.attrib.get('id')] = player.attrib.get('first') + ' ' + player.attrib.get('last')
# Out:
# Washington Nationals
#  645302 Victor Robles
#  475582 Ryan Zimmerman
#  543339 Daniel Hudson
#  594809 Adam Eaton
#  593833 Wander Suero
#  663432 Tanner Rainey
#  605452 Joe Ross
#  571431 Matt Adams
#  543685 Anthony Rendon
#  452678 Asdrubal Cabrera
#  543228 Yan Gomes
#  448281 Sean Doolittle
#  544931 Stephen Strasburg
#  435559 Kurt Suzuki
#  453286 Max Scherzer
#  571578 Patrick Corbin
#  407845 Fernando Rodney
#  665742 Juan Soto
#  572821 Brian Dozier
#  467827 Gerardo Parra
#  435062 Howie Kendrick
#  434671 Anibal Sanchez
#  572191 Michael A. Taylor
#  607208 Trea Turner
#  457915 Javy Guerra
# Houston Astros
#  455139 Robinson Chirinos
#  455117 Martin Maldonado
#  663656 Kyle Tucker
#  425844 Zack Greinke
#  608324 Alex Bregman
#  493329 Yuli Gurriel
#  444468 Hector Rondon
#  501789 Will Harris
#  606965 Chris Devenski
#  502210 Josh Reddick
#  514888 Jose Altuve
#  532077 Roberto Osuna
#  543807 George Springer
#  501925 Joe Smith
#  488726 Michael Brantley
#  664353 Jose Urquidy
#  649557 Aledmys Diaz
#  621043 Carlos Correa
#  519151 Ryan Pressly
#  502748 Brad Peacock
#  545350 Jake Marisnick
#  543037 Gerrit Cole
#  434378 Justin Verlander
#  657624 Josh James
#  670541 Yordan Alvarez

# %% [markdown]
# ### Innings data

# %%
# get innings - all data

url = 'http://gd2.mlb.com/components/game/mlb/year_2019/month_10/day_22/gid_2019_10_22_wasmlb_houmlb_1/inning/inning_all.xml'
resp = requests.get(url)
print(colored(resp, 'blue'))
# Out:
# <Response [200]>

# %%
xmlfile = 'HOU_WSH_Game1.xml'
with open(xmlfile, 'wb') as f:
    f.write(resp.content)
statinfo = os.stat(xmlfile)

# %%
tree = ET.parse(xmlfile)
root = tree.getroot()

# unpack the game to get all the innings
for child in root:
    print(child.tag, child.attrib.get('num'))
    for frame in child:
        print('   ', frame.tag, frame.attrib)
# Out:
# inning 1
#     top {}
#     bottom {}
# inning 2
#     top {}
#     bottom {}
# inning 3
#     top {}
#     bottom {}
# inning 4
#     top {}
#     bottom {}
# inning 5
#     top {}
#     bottom {}
# inning 6
#     top {}
#     bottom {}
# inning 7
#     top {}
#     bottom {}
# inning 8
#     top {}
#     bottom {}
# inning 9
#     top {}
#     bottom {}

# %%
# Convert data into a new data frame

frames = ['top', 'bottom']

pitchDictionary = { "FA":"fastball", "FF":"4-seam fb", "FT": "2-seam fb", "FC": "fb-cutter", "":"unknown", None: "none",
                    "FS":"fb-splitter", "SL":"slider", "CH":"changeup","CU":"curveball","KC":"knuckle-curve",
                    "KN":"knuckleball","EP":"eephus", "UN":"unidentified", "PO":"pitchout", "SI":"sinker", "SF":"split-finger"
                    }

PitchDF = pd.DataFrame(columns = ['pitchIdx', 'inning', 'frame', 'ab', 'abIdx', 'batter', 'stand', 'speed', 
                                  'pitchtype', 'px', 'pz', 'szTop', 'szBottom', 'des'])

colors = {'R':'red', 'L':'black'}
markers = {'R': 'x', 'L': 'o'}

# %% [markdown]
# ### Get pitch by pitch data

# %%
totalPitchCount = 0 
topPitchCount = 0 
bottomPitchCount = 0

innings = root.findall('./inning')
for inning in innings:
    for i in range(len(frames)):
        color = 'green' if i==0 else 'yellow' # show top in green and yellow for bottom
        print(colored('\nInning:' + inning.attrib.get('num') + '(', color, attrs=['reverse']))
        fr = inning.find(frames[i])
        if fr is not None:
            for ab in fr.iter('atbat'):
                battername = PlayerDict[ab.get('batter')]
                abPitchCount = 0 
                print(colored('   ' + battername, color, attrs=['bold']))
                
                pitches = ab.findall('pitch')
                #print(pitches)
                for pitch in pitches:
                    abPitchCount = abPitchCount + 1
                    totalPitchCount = totalPitchCount + 1
                    verbosePitch = pitchDictionary[pitch.get('pitch_type')]
                    print(colored('   ' + str(abPitchCount) + ': ' + verbosePitch))
                print('   ' + colored(ab.attrib.get('event'), color, attrs=['underline']))
print('Total Pitches:' + ' ' + str(totalPitchCount))
# Out:
# Inning:1(
#    Trea Turner
#    1: 4-seam fb
#    2: 4-seam fb
#    Single
#    Adam Eaton
#    1: knuckle-curve
#    2: 4-seam fb
#    Bunt Pop Out
#    Anthony Rendon
#    1: slider
#    2: 4-seam fb
#    3: 4-seam fb
#    Strikeout
#    Juan Soto
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    Strikeout
#
# Inning:1(
#    George Springer
#    1: slider
#    2: 4-seam fb
#    3: 4-seam fb
#    4: 4-seam fb
#    5: slider
#    6: slider
#    7: slider
#    Walk
#    Jose Altuve
#    1: 4-seam fb
#    Single
#    Michael Brantley
#    1: 4-seam fb
#    2: changeup
#    3: fb-cutter
#    Strikeout
#    Alex Bregman
#    1: slider
#    2: 4-seam fb
#    3: none
#    4: slider
#    5: slider
#    Strikeout
#    Yuli Gurriel
#    1: slider
#    2: 4-seam fb
#    3: slider
#    4: 4-seam fb
#    Double
#    Carlos Correa
#    1: 4-seam fb
#    2: slider
#    3: slider
#    4: 4-seam fb
#    5: slider
#    6: 4-seam fb
#    Strikeout
#
# Inning:2(
#    Howie Kendrick
#    1: 4-seam fb
#    2: 4-seam fb
#    3: slider
#    Groundout
#    Asdrubal Cabrera
#    1: knuckle-curve
#    2: 4-seam fb
#    3: 4-seam fb
#    4: 4-seam fb
#    5: changeup
#    Pop Out
#    Ryan Zimmerman
#    1: slider
#    2: 4-seam fb
#    Home Run
#    Kurt Suzuki
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    4: slider
#    5: slider
#    6: 4-seam fb
#    7: 4-seam fb
#    Groundout
#
# Inning:2(
#    Yordan Alvarez
#    1: curveball
#    2: 4-seam fb
#    3: curveball
#    4: 4-seam fb
#    5: 4-seam fb
#    6: fb-cutter
#    Walk
#    Martin Maldonado
#    1: slider
#    2: slider
#    3: slider
#    4: 4-seam fb
#    Flyout
#    Josh Reddick
#    1: curveball
#    2: 4-seam fb
#    3: 4-seam fb
#    4: 4-seam fb
#    5: curveball
#    6: 4-seam fb
#    Pop Out
#    George Springer
#    1: slider
#    2: 4-seam fb
#    3: 4-seam fb
#    4: changeup
#    5: 4-seam fb
#    6: changeup
#    Strikeout
#
# Inning:3(
#    Victor Robles
#    1: knuckle-curve
#    2: 4-seam fb
#    Pop Out
#    Trea Turner
#    1: 4-seam fb
#    2: knuckle-curve
#    Groundout
#    Adam Eaton
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    4: 4-seam fb
#    Single
#    Anthony Rendon
#    1: 4-seam fb
#    2: knuckle-curve
#    3: slider
#    4: 4-seam fb
#    5: 4-seam fb
#    6: 4-seam fb
#    7: slider
#    Flyout
#
# Inning:3(
#    Jose Altuve
#    1: 4-seam fb
#    2: curveball
#    3: slider
#    4: 4-seam fb
#    5: 4-seam fb
#    Flyout
#    Michael Brantley
#    1: 4-seam fb
#    2: fb-cutter
#    3: 4-seam fb
#    4: changeup
#    5: fb-cutter
#    Single
#    Alex Bregman
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    Strikeout
#    Yuli Gurriel
#    1: 4-seam fb
#    2: 4-seam fb
#    3: slider
#    Single
#    Carlos Correa
#    1: curveball
#    2: 4-seam fb
#    3: changeup
#    4: changeup
#    5: slider
#    Strikeout
#
# Inning:4(
#    Juan Soto
#    1: slider
#    2: 4-seam fb
#    Home Run
#    Howie Kendrick
#    1: slider
#    2: 4-seam fb
#    3: 4-seam fb
#    4: slider
#    5: slider
#    6: 4-seam fb
#    Flyout
#    Asdrubal Cabrera
#    1: knuckle-curve
#    2: slider
#    3: slider
#    Strikeout
#    Ryan Zimmerman
#    1: knuckle-curve
#    2: slider
#    3: slider
#    4: knuckle-curve
#    Strikeout
#
# Inning:4(
#    Yordan Alvarez
#    1: curveball
#    2: 4-seam fb
#    3: changeup
#    Single
#    Martin Maldonado
#    1: slider
#    2: slider
#    3: slider
#    4: 4-seam fb
#    5: changeup
#    6: 4-seam fb
#    Flyout
#    Josh Reddick
#    1: 4-seam fb
#    2: changeup
#    3: 4-seam fb
#    4: 4-seam fb
#    Flyout
#    George Springer
#    1: curveball
#    2: 4-seam fb
#    3: 4-seam fb
#    4: 4-seam fb
#    5: slider
#    6: slider
#    Walk
#    Jose Altuve
#    1: curveball
#    2: slider
#    3: 4-seam fb
#    4: changeup
#    5: 4-seam fb
#    6: 4-seam fb
#    7: curveball
#    8: slider
#    Groundout
#
# Inning:5(
#    Kurt Suzuki
#    1: knuckle-curve
#    2: slider
#    3: 4-seam fb
#    4: knuckle-curve
#    5: 4-seam fb
#    Walk
#    Victor Robles
#    1: slider
#    2: slider
#    3: 4-seam fb
#    Single
#    Trea Turner
#    1: knuckle-curve
#    2: slider
#    3: 4-seam fb
#    4: knuckle-curve
#    5: 4-seam fb
#    Lineout
#    Adam Eaton
#    1: 4-seam fb
#    2: slider
#    Single
#    Anthony Rendon
#    1: 4-seam fb
#    Forceout
#    Juan Soto
#    1: slider
#    2: knuckle-curve
#    3: knuckle-curve
#    4: slider
#    5: changeup
#    6: slider
#    Double
#    Howie Kendrick
#    1: 4-seam fb
#    2: knuckle-curve
#    3: slider
#    Lineout
#
# Inning:5(
#    Michael Brantley
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    Lineout
#    Alex Bregman
#    1: 4-seam fb
#    2: changeup
#    3: 4-seam fb
#    4: slider
#    5: slider
#    6: curveball
#    Groundout
#    Yuli Gurriel
#    1: slider
#    2: slider
#    3: 4-seam fb
#    4: 4-seam fb
#    5: changeup
#    6: slider
#    7: slider
#    Strikeout
#
# Inning:6(
#    Asdrubal Cabrera
#    1: 4-seam fb
#    2: 4-seam fb
#    3: knuckle-curve
#    4: 4-seam fb
#    5: knuckle-curve
#    Single
#    Ryan Zimmerman
#    1: 4-seam fb
#    Grounded Into DP
#    Kurt Suzuki
#    1: 4-seam fb
#    2: 4-seam fb
#    Pop Out
#
# Inning:6(
#    Carlos Correa
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    4: slider
#    5: slider
#    6: slider
#    Strikeout
#    Yordan Alvarez
#    1: slider
#    2: 4-seam fb
#    3: slider
#    4: 4-seam fb
#    Single
#    Martin Maldonado
#    1: slider
#    2: 2-seam fb
#    3: 4-seam fb
#    4: slider
#    5: 4-seam fb
#    6: slider
#    7: 4-seam fb
#    8: slider
#    Strikeout
#    Aledmys Diaz
#    1: 4-seam fb
#    2: slider
#    3: slider
#    Groundout
#
# Inning:7(
#    Victor Robles
#    1: 4-seam fb
#    2: 4-seam fb
#    3: slider
#    4: slider
#    Strikeout
#    Trea Turner
#    1: 4-seam fb
#    2: knuckle-curve
#    3: 4-seam fb
#    4: 4-seam fb
#    5: 4-seam fb
#    6: slider
#    7: 4-seam fb
#    8: 4-seam fb
#    Strikeout
#    Adam Eaton
#    1: 4-seam fb
#    2: changeup
#    Flyout
#
# Inning:7(
#    George Springer
#    1: 4-seam fb
#    2: slider
#    3: 4-seam fb
#    4: 4-seam fb
#    Home Run
#    Jose Altuve
#    1: 4-seam fb
#    2: 4-seam fb
#    3: slider
#    4: slider
#    Strikeout
#    Michael Brantley
#    1: slider
#    2: 4-seam fb
#    3: 4-seam fb
#    4: 4-seam fb
#    Walk
#    Alex Bregman
#    1: slider
#    2: slider
#    3: slider
#    4: 4-seam fb
#    5: 4-seam fb
#    6: 4-seam fb
#    7: 4-seam fb
#    Walk
#    Yuli Gurriel
#    1: slider
#    2: 4-seam fb
#    3: 4-seam fb
#    4: slider
#    Pop Out
#    Carlos Correa
#    1: slider
#    Single
#    Yordan Alvarez
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    Strikeout
#
# Inning:8(
#    Anthony Rendon
#    1: fb-cutter
#    2: fb-cutter
#    3: fb-cutter
#    4: fb-cutter
#    5: fb-cutter
#    Pop Out
#    Juan Soto
#    1: curveball
#    2: fb-cutter
#    3: curveball
#    Single
#    Howie Kendrick
#    1: curveball
#    2: fb-cutter
#    3: fb-cutter
#    4: fb-cutter
#    Flyout
#    Asdrubal Cabrera
#    1: curveball
#    2: curveball
#    3: curveball
#    4: curveball
#    5: curveball
#    6: curveball
#    Strikeout
#
# Inning:8(
#    Kyle Tucker
#    1: 4-seam fb
#    2: 4-seam fb
#    Single
#    Aledmys Diaz
#    1: 4-seam fb
#    2: 4-seam fb
#    Flyout
#    George Springer
#    1: slider
#    2: slider
#    3: 4-seam fb
#    4: slider
#    Double
#    Jose Altuve
#    1: 4-seam fb
#    2: 4-seam fb
#    3: slider
#    4: 4-seam fb
#    5: 4-seam fb
#    Lineout
#    Michael Brantley
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    4: 4-seam fb
#    Lineout
#
# Inning:9(
#    Ryan Zimmerman
#    1: sinker
#    Groundout
#    Kurt Suzuki
#    1: sinker
#    2: 4-seam fb
#    3: slider
#    4: slider
#    Strikeout
#    Victor Robles
#    1: slider
#    Pop Out
#
# Inning:9(
#    Alex Bregman
#    1: 4-seam fb
#    2: 4-seam fb
#    3: fb-splitter
#    4: 4-seam fb
#    5: 4-seam fb
#    Strikeout
#    Yuli Gurriel
#    1: 4-seam fb
#    2: 4-seam fb
#    3: 4-seam fb
#    Flyout
#    Carlos Correa
#    1: 4-seam fb
#    Lineout
# Total Pitches: 314

# %% [markdown]
# ### Pitch locations

# %%
for inning in innings:
    for i in range(len(frames)):
        fr = inning.find(frames[i])
        if fr is not None:
            for ab in fr.iter('atbat'):
                battername = PlayerDict[ab.get('batter')]
                standside = ab.get('stand')
                abIdx = ab.get('num')
                abPitchCount = 0 
                pitches = ab.findall('pitch')
                
                #print(pitches)
                for pitch in pitches:
                    if pitch.attrib.get('start_speed') is None:
                        speed = 0 
                    else:
                        speed = float(pitch.attrib.get('start_speed'))
                    pxfloat = 0.0 if pitch.attrib.get('px') == None else float('{0:.2f}'.format(float(pitch.attrib.get('px'))))
                    pzfloat = 0.0 if pitch.attrib.get('pz') == None else float('{0:.2f}'.format(float(pitch.attrib.get('pz'))))
                    szTop = 0.0 if pitch.attrib.get('sz_top') == None else float('{0:.2f}'.format(float(pitch.attrib.get('sz_top'))))
                    szBot = 0.0 if pitch.attrib.get('sz_bot') == None else float('{0:.2f}'.format(float(pitch.attrib.get('sz_bot'))))
                    print(pxfloat, pzfloat, szTop, szBot)
                    
                    abPitchCount = abPitchCount + 1
                    totalPitchCount = totalPitchCount + 1
                    
                    if frames[i] =='top':
                        topPitchCount = topPitchCount + 1
                    else:
                        bottomPitchCount = bottomPitchCount + 1
                    inn = inning.attrib.get('num')
                    des = pitch.get('des')    
                    verbosePitch = pitchDictionary[pitch.get('pitch_type')]
                    
                    PitchDF.loc[totalPitchCount] = [totalPitchCount, inn, frames[i], abIdx, abPitchCount, battername, 
                                                   standside, speed, verbosePitch, pxfloat, pzfloat, szTop, szBot, des]

print(str(totalPitchCount) + " pitches cataloged. Top: " + str(topPitchCount) + ". Bottom: " + str(bottomPitchCount) + ".")
# Out:
# 0.63 3.79 3.18 1.59
# 0.52 2.5 3.34 1.63
# 0.88 1.27 2.95 1.38
# 0.2 2.54 3.06 1.44
# 0.35 2.22 3.17 1.51
# 0.39 2.72 3.17 1.51
# 0.32 3.41 3.14 1.53
# -0.09 2.93 3.14 1.53
# 0.47 2.87 3.23 1.57
# -0.61 2.73 3.45 1.58
# -0.43 2.47 3.4 1.53
# 1.05 2.27 3.39 1.51
# 1.02 2.13 3.35 1.55
# 0.45 3.02 3.45 1.58
# -0.48 2.2 3.45 1.58
# 1.4 0.62 3.45 1.49
# -0.71 3.34 3.37 1.52
# 0.26 2.99 2.9 1.34
# 1.01 2.53 3.31 1.48
# 0.55 2.33 3.46 1.59
# 0.78 1.34 3.24 1.54
# 0.88 1.25 3.24 1.54
# 0.57 2.08 3.35 1.6
# 0.0 0.0 3.36 1.7
# 1.19 0.01 3.36 1.57
# 0.19 1.44 3.24 1.54
# 0.72 1.34 3.36 1.59
# -0.4 2.35 3.36 1.59
# 1.25 -0.4 3.41 1.66
# -0.32 3.69 3.36 1.59
# -0.28 3.63 3.53 1.66
# -0.35 1.84 3.54 1.64
# 0.69 1.36 3.59 1.63
# 1.28 2.98 3.52 1.67
# 0.75 0.97 3.48 1.58
# 0.66 3.42 3.52 1.67
# -0.48 2.15 2.97 1.28
# 0.91 3.03 3.08 1.34
# 0.75 1.78 3.37 1.62
# -0.94 3.04 3.52 1.64
# -1.0 2.6 3.37 1.62
# -0.82 2.61 3.37 1.62
# -0.99 3.91 3.37 1.62
# -1.06 2.55 3.37 1.62
# -0.2 4.04 3.63 1.79
# 0.07 2.66 3.47 1.67
# 1.36 1.17 3.04 1.4
# 0.85 1.95 3.12 1.4
# 0.61 2.98 3.18 1.44
# -0.41 3.46 3.05 1.42
# 1.97 1.76 3.14 1.4
# -0.01 2.66 3.05 1.42
# 0.57 2.49 3.05 1.42
# -1.28 2.64 3.53 1.76
# 1.41 2.85 3.45 1.71
# -0.85 2.02 3.51 1.73
# -1.64 2.65 3.53 1.73
# -0.41 1.83 3.52 1.74
# 0.79 0.16 3.51 1.71
# 0.02 1.75 3.43 1.53
# 0.33 1.22 3.47 1.67
# 1.24 0.49 3.47 1.63
# 0.42 3.21 3.29 1.51
# -1.28 1.96 3.34 1.71
# -1.07 2.74 3.29 1.65
# -0.56 2.89 3.29 1.51
# 1.15 1.92 3.25 1.69
# -0.24 1.35 3.29 1.51
# 0.1 2.95 3.29 1.51
# 0.33 2.12 3.45 1.58
# 0.23 1.95 3.5 1.57
# 1.69 2.97 3.46 1.55
# -0.71 1.26 3.48 1.59
# 1.48 1.47 3.43 1.55
# -0.57 1.76 3.46 1.59
# -1.0 3.47 3.12 1.43
# -0.72 3.16 3.26 1.53
# 1.34 2.54 3.31 1.73
# -0.18 2.07 3.34 1.63
# -0.33 3.07 3.11 1.43
# 0.71 2.56 3.06 1.44
# 1.25 3.5 3.04 1.42
# -1.17 2.45 3.06 1.44
# -0.47 3.14 3.17 1.51
# 0.93 2.86 3.11 1.49
# 1.05 1.03 3.13 1.39
# 1.38 2.51 3.08 1.4
# 0.59 2.22 3.17 1.51
# -0.71 3.31 3.17 1.51
# 0.3 2.59 3.17 1.51
# -0.19 2.6 2.93 1.34
# -0.7 1.49 2.9 1.28
# 0.97 0.36 2.92 1.3
# 0.27 2.14 2.9 1.34
# -0.48 1.95 3.31 1.48
# -0.86 2.53 3.31 1.48
# -0.19 3.51 3.31 1.48
# -0.94 3.63 3.31 1.48
# -1.34 1.56 3.56 1.59
# -0.06 2.87 3.24 1.54
# 0.74 2.12 3.27 1.61
# -0.82 2.53 3.31 1.7
# 0.84 3.51 3.24 1.54
# 1.0 0.64 3.38 1.59
# -0.43 3.79 3.35 1.62
# 0.53 2.63 3.36 1.59
# -0.34 2.0 3.54 1.66
# 0.33 2.66 3.52 1.67
# 0.33 0.07 3.52 1.64
# 0.79 -0.33 3.56 1.7
# 2.12 1.34 3.14 1.53
# 0.89 3.31 3.27 1.57
# -0.36 3.05 3.14 1.53
# 1.3 0.24 3.04 1.3
# 0.8 2.31 3.12 1.4
# -0.58 3.27 3.12 1.4
# 1.37 0.41 3.03 1.28
# 0.52 2.46 3.12 1.4
# -0.16 3.14 3.37 1.62
# -0.86 2.59 3.43 1.67
# 0.01 2.66 3.37 1.62
# 0.77 2.1 3.47 1.67
# 0.83 1.5 3.52 1.74
# 1.52 1.22 3.48 1.7
# -0.09 3.11 3.38 1.58
# -0.1 0.79 3.05 1.42
# -1.86 2.53 3.6 1.77
# -1.09 2.83 3.41 1.63
# -0.91 2.37 3.47 1.67
# 0.62 1.91 3.47 1.67
# -0.59 2.69 3.47 1.67
# 1.36 -0.46 3.5 1.62
# 1.18 2.07 3.42 1.62
# 0.49 0.59 3.45 1.57
# -0.3 2.7 3.47 1.67
# -0.12 3.51 3.29 1.51
# -1.15 2.41 3.41 1.74
# -1.11 2.34 3.4 1.7
# 0.04 2.67 3.29 1.51
# 1.33 0.95 3.42 1.57
# 1.27 1.39 3.44 1.61
# 0.06 1.92 3.46 1.51
# 1.17 1.3 3.43 1.55
# 0.49 1.8 3.45 1.58
# 0.55 0.75 3.41 1.52
# -0.17 2.66 2.9 1.34
# 1.25 2.59 2.61 0.98
# 0.31 2.22 2.9 1.34
# -0.08 0.66 2.88 1.3
# 0.27 2.39 2.9 1.34
# 1.25 1.08 2.89 1.24
# -0.59 1.52 2.9 1.34
# -0.03 1.8 2.9 1.34
# 1.16 0.31 3.09 1.36
# 0.88 1.28 3.13 1.46
# 0.45 1.94 3.16 1.42
# 0.6 0.77 3.01 1.4
# -0.54 4.07 3.04 1.4
# -0.66 2.71 3.28 1.41
# 0.77 2.97 3.26 1.53
# -0.2 3.05 3.34 1.63
# -0.06 0.5 3.28 1.66
# -0.39 2.08 3.34 1.63
# 1.28 2.05 3.32 1.66
# 1.27 0.64 3.28 1.62
# 0.08 2.05 3.34 1.63
# 0.39 2.17 3.12 1.39
# 0.7 2.1 3.17 1.51
# -0.93 2.1 3.17 1.51
# 1.66 1.37 3.24 1.62
# -0.97 3.13 3.21 1.71
# -1.22 3.94 3.23 1.63
# 0.22 1.89 3.22 1.57
# 0.14 2.02 3.14 1.53
# -0.37 1.86 3.14 1.53
# 0.47 2.4 3.12 1.4
# -0.36 0.83 3.08 1.34
# 0.34 2.6 3.37 1.62
# -1.27 2.42 3.45 1.57
# -0.64 2.5 3.31 1.48
# 0.5 2.28 3.24 1.54
# -0.78 1.92 3.45 1.67
# -0.17 1.01 3.23 1.63
# 1.09 2.3 3.23 1.63
# 0.57 1.44 3.32 1.63
# 0.71 0.39 3.29 1.71
# -0.7 1.9 3.36 1.59
# -0.54 2.91 3.36 1.59
# 1.16 0.67 3.26 1.58
# -1.98 2.65 3.36 1.68
# -0.49 2.41 3.36 1.59
# -0.73 2.07 3.36 1.59
# 0.65 1.48 3.36 1.59
# 0.07 1.08 3.36 1.59
# -0.17 1.25 3.44 1.69
# 0.37 1.58 3.47 1.7
# -0.3 2.33 3.37 1.62
# -0.89 2.83 3.42 1.63
# -0.16 3.19 3.47 1.67
# 0.14 3.01 3.05 1.42
# 0.7 2.53 3.14 1.38
# 0.21 3.17 3.52 1.67
# -0.98 0.76 3.6 1.69
# -1.07 3.09 3.54 1.72
# 0.7 2.81 3.52 1.67
# -0.76 2.63 3.52 1.67
# -1.2 1.39 3.59 1.71
# -1.36 1.61 3.41 1.63
# -1.73 -0.37 3.58 1.79
# 1.1 3.1 3.69 1.79
# -0.62 2.25 3.41 1.63
# 0.25 2.69 3.47 1.67
# -1.13 1.42 3.48 1.61
# 1.0 2.9 3.47 1.67
# -1.27 2.78 3.55 1.67
# -0.82 0.81 3.47 1.67
# -0.77 3.13 3.47 1.67
# -0.31 1.61 3.47 1.67
# 0.38 4.31 3.49 1.58
# -0.37 1.4 3.47 1.67
# 0.83 3.27 3.34 1.59
# 0.19 2.83 3.34 1.59
# -0.22 1.7 3.45 1.58
# 0.87 2.77 3.29 1.49
# 0.71 2.62 3.29 1.5
# 1.34 1.01 3.22 1.47
# 1.2 1.03 3.34 1.63
# 0.93 2.0 3.27 1.65
# 0.68 1.08 3.29 1.65
# 1.27 2.69 3.31 1.66
# -0.12 3.09 3.15 1.58
# -0.59 1.39 3.34 1.63
# -0.96 3.13 3.34 1.63
# 0.28 2.47 3.34 1.63
# 1.19 2.28 3.06 1.44
# 0.4 2.17 3.0 1.42
# -0.42 2.2 3.45 1.58
# -0.45 2.96 3.45 1.58
# 0.44 0.79 3.45 1.61
# -1.13 2.37 3.44 1.58
# -0.57 2.1 3.45 1.58
# 0.54 2.38 2.94 1.29
# 0.17 1.6 2.82 1.31
# 1.14 0.57 2.69 1.21
# 1.37 1.08 3.31 1.48
# -0.59 1.56 3.35 1.59
# -0.9 1.02 3.47 1.59
# -1.52 2.52 3.42 1.53
# -0.84 3.45 3.42 1.53
# 0.45 1.4 3.23 1.63
# 0.51 1.39 3.23 1.57
# 0.98 1.4 3.12 1.55
# 0.38 2.35 3.26 1.61
# -0.8 1.93 3.17 1.57
# 0.07 2.19 3.24 1.54
# -0.42 0.97 3.23 1.57
# 0.5 3.09 3.36 1.59
# 0.98 2.62 3.34 1.64
# 0.45 2.37 3.36 1.59
# -0.05 3.28 3.36 1.59
# -0.15 3.12 3.52 1.67
# -0.69 2.11 3.71 1.84
# 0.17 2.89 3.41 1.63
# -0.37 3.95 3.41 1.63
# 1.53 3.24 3.28 1.54
# 0.79 3.23 3.21 1.55
# 0.05 3.42 3.17 1.51
# 1.66 2.72 3.22 1.53
# 0.1 2.42 3.17 1.51
# -0.34 2.45 3.23 1.56
# 1.06 3.3 3.14 1.53
# -0.11 3.01 3.12 1.4
# -0.21 2.96 2.96 1.28
# 0.83 3.19 3.08 1.34
# -0.14 3.23 3.12 1.4
# -0.62 3.35 3.37 1.62
# -0.34 2.25 3.41 1.6
# 0.47 1.66 3.37 1.62
# 0.1 1.42 3.37 1.62
# -0.49 -0.01 3.44 1.59
# 0.37 0.3 3.45 1.66
# 0.16 0.52 3.47 1.67
# -0.52 3.41 3.56 1.67
# -0.39 3.6 3.34 1.59
# 0.23 1.81 3.51 1.68
# -0.34 2.18 3.45 1.58
# 1.55 1.95 3.51 1.57
# -0.1 2.32 3.45 1.58
# -0.15 5.11 3.61 1.63
# 0.34 2.64 3.53 1.54
# 0.82 2.83 2.9 1.34
# 1.45 3.02 2.88 1.29
# 2.07 0.58 2.9 1.34
# -0.26 2.63 2.9 1.34
# 1.2 1.5 3.31 1.48
# -0.21 3.15 3.52 1.52
# -0.91 2.01 3.41 1.57
# -0.51 4.0 3.31 1.48
# -0.49 2.76 3.47 1.67
# -0.69 2.13 3.05 1.42
# 0.15 1.55 3.08 1.42
# -0.92 3.32 3.11 1.39
# 0.03 2.6 3.05 1.42
# -0.38 2.9 3.23 1.48
# -0.79 2.63 3.24 1.54
# 1.1 2.79 3.2 1.57
# 0.85 2.82 3.33 1.59
# 1.74 2.05 3.28 1.65
# 0.07 2.32 3.23 1.62
# 0.54 2.57 3.24 1.54
# 1.27 2.58 3.31 1.54
# 0.27 1.46 3.43 1.69
# 0.63 2.9 3.52 1.67
# 0.19 3.29 3.34 1.63
# 628 pitches cataloged. Top: 128. Bottom: 186.

# %% [markdown]
# ### Save data

# %%
PitchDF.to_csv('PitchDF_NatsGame1.csv')

# %% [markdown]
# ### Scherzer's performance

# %%
# Slice out just Max pitches

PitchDF['inning'] = PitchDF['inning'].astype(int)
Max = PitchDF.loc[(PitchDF['frame']=='bottom') & (PitchDF['inning']<6)]

# %%
# Organize pitch data

uniqueDesList = Max['des'].unique()
#print(uniqueDesList)

ballColList = []
strikeColList = []
ballCount = 0 
strikeCount = 0

for index, row in Max.iterrows():
    des = row['des']
    #print(des)
    if row['abIdx'] == 1:
        ballCount = 0 
        strikeCount = 0 

    # save the count
    ballColList.append(ballCount)
    strikeColList.append(strikeCount)
    
    if 'Ball' in des:
        ballCount = ballCount +1
    elif 'Foul' in des:
        if strikeCount is not 2:
            strikeCount = strikeCount +1
    elif 'Strike' in des:
        strikeCount = strikeCount +1
    
Max['ballCount'] = ballColList
Max['strikeCount'] = strikeColList
# Out:
# /Users/Kelly/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Kelly/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# What pitches did he throw?

Max['pitchtype'].unique()
# Out:
# array(['slider', '4-seam fb', 'changeup', 'fb-cutter', 'none',
#        'curveball'], dtype=object)

# %% [markdown]
# ### Speed

# %%
print('Average speed of 4-seam fastball: ' + str(np.mean(Max.loc[Max['pitchtype']=='4-seam fb']['speed'])))
print('Average speed of changeup: ' + str(np.mean(Max.loc[Max['pitchtype']=='changeup']['speed'])))
print('Average speed of curveball: ' + str(np.mean(Max.loc[Max['pitchtype']=='curveball']['speed'])))
print('Average speed of slider: ' + str(np.mean(Max.loc[Max['pitchtype']=='slider']['speed'])))
# Out:
# Average speed of 4-seam fastball: 95.03269230769234
# Average speed of changeup: 84.96666666666667
# Average speed of curveball: 78.57272727272726
# Average speed of slider: 85.53124999999999

# %%
# There is one missing value for a pitch to Alex Bregman (pitchIdx = 338), fill with average velocity 
# of a 4-seam fb

fill = round(np.mean(Max.loc[Max['pitchtype']=='4-seam fb']['speed']), 1)
Max['pitchtype'].replace("none", value="4-seam fb", inplace=True)
Max['speed'].replace(0.0, value=fill, inplace=True)

# %%
Max.head(15)
# Out:
#      pitchIdx  inning   frame ab abIdx            batter stand      speed  \
# idx
# 325     325.0       1  bottom  5     1   George Springer     R  86.300000
# 326     326.0       1  bottom  5     2   George Springer     R  97.000000
# 327     327.0       1  bottom  5     3   George Springer     R  96.200000
# 328     328.0       1  bottom  5     4   George Springer     R  96.700000
# 329     329.0       1  bottom  5     5   George Springer     R  86.600000
# 330     330.0       1  bottom  5     6   George Springer     R  86.900000
# 331     331.0       1  bottom  5     7   George Springer     R  87.000000
# 332     332.0       1  bottom  6     1       Jose Altuve     R  94.700000
# 333     333.0       1  bottom  7     1  Michael Brantley     L  96.600000
# 334     334.0       1  bottom  7     2  Michael Brantley     L  87.100000
# 335     335.0       1  bottom  7     3  Michael Brantley     L  90.500000
# 336     336.0       1  bottom  8     1      Alex Bregman     R  85.800000
# 337     337.0       1  bottom  8     2      Alex Bregman     R  96.800000
# 338     338.0       1  bottom  8     3      Alex Bregman     R  93.239623
# 339     339.0       1  bottom  8     4      Alex Bregman     R  85.000000
#
#      pitchtype    px    pz  szTop  szBottom              des  ballCount  \
# idx
# 325     slider -0.43  2.47   3.40      1.53    Called Strike          0
# 326  4-seam fb  1.05  2.27   3.39      1.51             Ball          0
# 327  4-seam fb  1.02  2.13   3.35      1.55             Ball          1
# 328  4-seam fb  0.45  3.02   3.45      1.58             Foul          2
# 329     slider -0.48  2.20   3.45      1.58             Foul          2
# 330     slider  1.40  0.62   3.45      1.49             Ball          2
# 331     slider -0.71  3.34   3.37      1.52             Ball          3
# 332  4-seam fb  0.26  2.99   2.90      1.34  In play, no out          0
# 333  4-seam fb  1.01  2.53   3.31      1.48  Swinging Strike          0
# 334   changeup  0.55  2.33   3.46      1.59    Called Strike          0
# 335  fb-cutter  0.78  1.34   3.24      1.54  Swinging Strike          0
# 336     slider  0.88  1.25   3.24      1.54  Swinging Strike          0
# 337  4-seam fb  0.57  2.08   3.35      1.60    Called Strike          0
# 338  4-seam fb  0.00  0.00   3.36      1.70             Ball          0
# 339     slider  1.19  0.01   3.36      1.57     Ball In Dirt          1
#
#      strikeCount
# idx
# 325            0
# 326            1
# 327            1
# 328            1
# 329            2
# 330            2
# 331            2
# 332            0
# 333            0
# 334            1
# 335            2
# 336            0
# 337            1
# 338            2
# 339            2

# %% [markdown]
# ### Velocity change per pitch

# %%
lines = Max.plot.line(x = 'pitchIdx', y = 'speed', figsize = [12,6])

# %%
color= ['yellow' if f=='top' else 'green' for f in Max['frame'].tolist()]
Max.index.rename('idx', inplace=True)
Max['pitchIdx'] = Max['pitchIdx'].astype(float)
Max.dtypes
Max.plot(kind='scatter',x='pitchIdx', y='speed', color=color,  figsize=[12,6])
# Out:
# /Users/Kelly/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Pitch type by pitch counts

# %%
titleList = []
dataList = []
fig, axes = plt.subplots(4,3, figsize=[16,21])

for b in range(4):
    for s in range(3):
        #print('Count:', str(b), str(s))
        df2 = Max.loc[(Max['ballCount']==b) & (Max['strikeCount']==s)]
        title = 'Count:' + str(b) + ' ' + str(s) + '(' + str(len(df2)) + ')'
        titleList.append(title)
        dataList.append(df2)
for i, ax in enumerate(axes.flatten()):
    x = dataList[i].pitchtype.value_counts()
    l = dataList[i].pitchtype.unique()
    #print(x)
    ax.pie(x, radius = 1, autopct="%.1f%%", pctdistance=0.9, labels=l)
    ax.set_title(titleList[i])

plt.show()
